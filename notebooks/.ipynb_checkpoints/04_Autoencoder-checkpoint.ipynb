# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# Load preprocessed data
X_train = pd.read_csv("../data/processed/X_train_scaled.csv")
X_all = pd.read_csv("../data/processed/X_all_scaled.csv")
y_all = pd.read_csv("../data/processed/y_all.csv")

# Build Autoencoder model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.callbacks import EarlyStopping

input_dim = X_train.shape[1]
input_layer = Input(shape=(input_dim,))

# Encoder
encoded = Dense(16, activation='relu')(input_layer)
encoded = Dense(8, activation='relu')(encoded)

# Decoder
decoded = Dense(16, activation='relu')(encoded)
decoded = Dense(input_dim, activation='linear')(decoded)

# Autoencoder
autoencoder = Model(inputs=input_layer, outputs=decoded)
autoencoder.compile(optimizer='adam', loss='mse')

# Train the model
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = autoencoder.fit(
    X_train, X_train,
    epochs=100,
    batch_size=256,
    validation_split=0.1,
    callbacks=[early_stop],
    verbose=1
)

# Predict and compute reconstruction error
X_all_pred = autoencoder.predict(X_all)
reconstruction_error = np.mean(np.power(X_all - X_all_pred, 2), axis=1)

# Threshold from 95th percentile of normal data
threshold = np.percentile(reconstruction_error[y_all.values.flatten() == 0], 95)
y_pred = (reconstruction_error > threshold).astype(int)

# Evaluation
print("Confusion Matrix:")
print(confusion_matrix(y_all, y_pred))

print("\nClassification Report:")
print(classification_report(y_all, y_pred))

print("\nROC-AUC Score:")
print(roc_auc_score(y_all, y_pred))

# Confusion Matrix Plot
plt.figure(figsize=(6, 5))
sns.heatmap(confusion_matrix(y_all, y_pred), annot=True, fmt='d', cmap='Reds',
            xticklabels=['Pred: Normal', 'Pred: Attack'],
            yticklabels=['Actual: Normal', 'Actual: Attack'])
plt.title("Autoencoder - Confusion Matrix")
plt.show()

# Save model and threshold
autoencoder.save("../models/autoencoder_model.h5")
joblib.dump(threshold, "../models/autoencoder_threshold.pkl")

print(f"Autoencoder model trained and saved. Threshold: {threshold:.6f}")
# Out:
# Epoch 1/100
# 342/342 [==============================] - 4s 6ms/step - loss: 0.5572 - val_loss: 0.4561
# Epoch 2/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.2070 - val_loss: 0.2733
# Epoch 3/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.1193 - val_loss: 0.1101
# Epoch 4/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0550 - val_loss: 0.0371
# Epoch 5/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0312 - val_loss: 0.0284
# Epoch 6/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0220 - val_loss: 0.0163
# Epoch 7/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0176 - val_loss: 0.0144
# Epoch 8/100
# 342/342 [==============================] - 2s 6ms/step - loss: 0.0135 - val_loss: 0.0115
# Epoch 9/100
# 342/342 [==============================] - 2s 6ms/step - loss: 0.0111 - val_loss: 0.0093
# Epoch 10/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0095 - val_loss: 0.0076
# Epoch 11/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0080 - val_loss: 0.0071
# Epoch 12/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0070 - val_loss: 0.0065
# Epoch 13/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0062 - val_loss: 0.0066
# Epoch 14/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0055 - val_loss: 0.0049
# Epoch 15/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0050 - val_loss: 0.0043
# Epoch 16/100
# 342/342 [==============================] - 2s 6ms/step - loss: 0.0047 - val_loss: 0.0054
# Epoch 17/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 18/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0041 - val_loss: 0.0038
# Epoch 19/100
# 342/342 [==============================] - 2s 6ms/step - loss: 0.0039 - val_loss: 0.0039
# Epoch 20/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0036 - val_loss: 0.0038
# Epoch 21/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0033 - val_loss: 0.0037
# Epoch 22/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0033 - val_loss: 0.0030
# Epoch 23/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 0.0030
# Epoch 24/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0030 - val_loss: 0.0031
# Epoch 25/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 26/100
# 342/342 [==============================] - 2s 7ms/step - loss: 0.0025 - val_loss: 0.0041
# Epoch 27/100
# 342/342 [==============================] - 2s 7ms/step - loss: 0.0028 - val_loss: 0.0039
# Epoch 28/100
# 342/342 [==============================] - 2s 7ms/step - loss: 0.0024 - val_loss: 0.0022
# Epoch 29/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 30/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0022 - val_loss: 0.0022
# Epoch 31/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0021 - val_loss: 0.0022
# Epoch 32/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0020 - val_loss: 0.0023
# Epoch 33/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 34/100
# 342/342 [==============================] - 1s 3ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 35/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 36/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0025
# Epoch 37/100
# 342/342 [==============================] - 2s 6ms/step - loss: 0.0018 - val_loss: 0.0023
# Epoch 38/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 39/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0015
# Epoch 40/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 41/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0017 - val_loss: 0.0017
# Epoch 42/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 43/100
# 342/342 [==============================] - 2s 5ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 44/100
# 342/342 [==============================] - 1s 4ms/step - loss: 0.0015 - val_loss: 0.0017
# 15439/15439 [==============================] - 36s 2ms/step
# Confusion Matrix:
# [[ 92414   4864]
#  [  6389 390354]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94     97278
#            1       0.99      0.98      0.99    396743
#
#     accuracy                           0.98    494021
#    macro avg       0.96      0.97      0.96    494021
# weighted avg       0.98      0.98      0.98    494021
#
#
# ROC-AUC Score:
# 0.9669476741309512
# ✅ Autoencoder model trained and saved. Threshold: 0.001540
